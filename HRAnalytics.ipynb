# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("C:\\Users\\yeshwanthr\\Documents\\Jupiter nb python files\\HRAnalytics\\HR_comma_sep.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df.left.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.left.value_counts()
# Out:
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.Department.unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
label_encoder.fit_transform(df['Department'])
# Out:
# array([7, 7, 7, ..., 8, 8, 8])

# %%
label_encoder.fit_transform(df['Department']).shape
# Out:
# (14999,)

# %%
df.Department.shape
# Out:
# (14999,)

# %%
df['Department']=label_encoder.fit_transform(df['Department'])

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.salary.unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
df.replace({'low':1,'medium':2,'high':3},inplace=True)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.satisfaction_level.unique()
# Out:
# array([0.38, 0.8 , 0.11, 0.72, 0.37, 0.41, 0.1 , 0.92, 0.89, 0.42, 0.45,
#        0.84, 0.36, 0.78, 0.76, 0.09, 0.46, 0.4 , 0.82, 0.87, 0.57, 0.43,
#        0.13, 0.44, 0.39, 0.85, 0.81, 0.9 , 0.74, 0.79, 0.17, 0.24, 0.91,
#        0.71, 0.86, 0.14, 0.75, 0.7 , 0.31, 0.73, 0.83, 0.32, 0.54, 0.27,
#        0.77, 0.88, 0.48, 0.19, 0.6 , 0.12, 0.61, 0.33, 0.56, 0.47, 0.28,
#        0.55, 0.53, 0.59, 0.66, 0.25, 0.34, 0.58, 0.51, 0.35, 0.64, 0.5 ,
#        0.23, 0.15, 0.49, 0.3 , 0.63, 0.21, 0.62, 0.29, 0.2 , 0.16, 0.65,
#        0.68, 0.67, 0.22, 0.26, 0.99, 0.98, 1.  , 0.52, 0.93, 0.97, 0.69,
#        0.94, 0.96, 0.18, 0.95])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  int32
#  9   salary                 14999 non-null  int64
# dtypes: float64(2), int32(1), int64(7)
# memory usage: 1.1 MB

# %%
sns.scatterplot(data=df,x='satisfaction_level',y='left')
# Out:
# <Axes: xlabel='satisfaction_level', ylabel='left'>

# %%
sns.scatterplot(data=df,x='last_evaluation',y='left')
# Out:
# <Axes: xlabel='last_evaluation', ylabel='left'>

# %%
sns.scatterplot(data=df,x='number_project',y='left')
# Out:
# <Axes: xlabel='number_project', ylabel='left'>

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department  \
# 0                   3              0     1                      0           7
# 1                   6              0     1                      0           7
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7
#
#    salary
# 0       1
# 1       2
# ...

# %%
df.time_spend_company.unique()
# Out:
# array([ 3,  6,  4,  5,  2,  8, 10,  7], dtype=int64)

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department  \
# 0                   3              0     1                      0           7
# 1                   6              0     1                      0           7
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7
#
#    salary
# 0       1
# 1       2
# ...

# %%
sns.countplot(x='Work_accident',hue='left',data=df)
# Out:
# <Axes: xlabel='Work_accident', ylabel='count'>

# %%
sns.countplot(x='promotion_last_5years',hue='left',data=df)
# Out:
# <Axes: xlabel='promotion_last_5years', ylabel='count'>

# %%
sns.countplot(x='salary',hue='left',data=df)
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %%
sns.countplot(x='Department',hue='left',data=df)
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
sns.scatterplot(x='last_evaluation',y='left',data=df)
# Out:
# <Axes: xlabel='last_evaluation', ylabel='left'>

# %%
sns.scatterplot(x='satisfaction_level',y='left',data=df)
# Out:
# <Axes: xlabel='satisfaction_level', ylabel='left'>

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dummies=pd.get_dummies(df.salary,dtype='int64',drop_first=True)

# %%
dummies
# Out:
#        2  3
# 0      0  0
# 1      1  0
# 2      1  0
# 3      0  0
# 4      0  0
# ...   .. ..
# 14994  0  0
# 14995  0  0
# 14996  0  0
# 14997  0  0
# 14998  0  0
#
# [14999 rows x 2 columns]

# %%
df=pd.concat([df,dummies],axis=1)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.drop('salary',axis=1,inplace=True)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
y = df.left
x = df.drop(columns = ['left','Department','Work_accident'])

# %%
xtrain , xtest , ytrain , ytest = train_test_split(x,y, test_size = 0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
xtrain
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 9838                 1.00             0.61               3
# 7689                 0.16             0.78               4
# 6557                 0.80             0.80               3
# 6872                 0.66             0.86               4
# 820                  0.11             0.93               7
# ...                   ...              ...             ...
# 5191                 0.52             0.96               4
# 13418                0.49             0.65               4
# 5390                 0.66             0.73               5
# 860                  0.79             1.00               4
# 7270                 0.98             0.86               2
#
#        average_montly_hours  time_spend_company  promotion_last_5years  2  3
# 9838                    188                   4                      0  0  0
# 7689                    196                   5                      0  0  1
# ...

# %%
ytrain
# Out:
# 9838     0
# 7689     0
# 6557     0
# 6872     0
# 820      1
#         ..
# 5191     0
# 13418    0
# 5390     0
# 860      1
# 7270     0
# Name: left, Length: 11999, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  int32
#  9   2                      14999 non-null  int64
#  10  3                      14999 non-null  int64
# dtypes: float64(2), int32(1), int64(8)
# memory usage: 1.2 MB

# %%
df.columns
# Out:
# Index([   'satisfaction_level',       'last_evaluation',
#               'number_project',  'average_montly_hours',
#           'time_spend_company',         'Work_accident',
#                         'left', 'promotion_last_5years',
#                   'Department',                       2,
#                              3],
#       dtype='object')

# %%
dummies
# Out:
#        2  3
# 0      0  0
# 1      1  0
# 2      1  0
# 3      0  0
# 4      0  0
# ...   .. ..
# 14994  0  0
# 14995  0  0
# 14996  0  0
# 14997  0  0
# 14998  0  0
#
# [14999 rows x 2 columns]

# %%
dummies.columns
# Out:
# Index([2, 3], dtype='int64')

# %%
df.columns
# Out:
# Index([   'satisfaction_level',       'last_evaluation',
#               'number_project',  'average_montly_hours',
#           'time_spend_company',         'Work_accident',
#                         'left', 'promotion_last_5years',
#                   'Department',                       2,
#                              3],
#       dtype='object')

# %%
dummies.columns=['med','high']

# %%
dummies
# Out:
#        med  high
# 0        0     0
# 1        1     0
# 2        1     0
# 3        0     0
# 4        0     0
# ...    ...   ...
# 14994    0     0
# 14995    0     0
# 14996    0     0
# 14997    0     0
# 14998    0     0
#
# [14999 rows x 2 columns]

# %%
df=pd.concat([df,dummies],axis=1)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.drop(2)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
x1 = df.drop(columns = ['left','Department','Work_accident',2,3])

# %%
x1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  promotion_last_5years  med  \
# 0                       157                   3                      0    0
# 1                       262                   6                      0    1
# ...

# %%
x=x1

# %%
xtrain , xtest , ytrain , ytest = train_test_split(x,y, test_size = 0.2,random_state=42)

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(xtest,ytest)
# Out:
# 0.758

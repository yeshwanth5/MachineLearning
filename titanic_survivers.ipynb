# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\yeshwanthr\\Documents\\Jupiter nb python files\\titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(['PassengerId','Name','Ticket','Cabin','SibSp','Parch','Embarked'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
df.Sex=label_encoder.fit_transform(df.Sex)

# %%
df
# Out:
#      Survived  Pclass  Sex   Age     Fare
# 0           0       3    1  22.0   7.2500
# 1           1       1    0  38.0  71.2833
# 2           1       3    0  26.0   7.9250
# 3           1       1    0  35.0  53.1000
# 4           0       3    1  35.0   8.0500
# ..        ...     ...  ...   ...      ...
# 886         0       2    1  27.0  13.0000
# 887         1       1    0  19.0  30.0000
# 888         0       3    0   NaN  23.4500
# 889         1       1    1  26.0  30.0000
# 890         0       3    1  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
label_encoder.classes_
# Out:
# array(['female', 'male'], dtype=object)

# %%
label_encoder.transform(label_encoder.classes_)
# Out:
# array([0, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int32
#  3   Age       714 non-null    float64
#  4   Fare      891 non-null    float64
# dtypes: float64(2), int32(1), int64(2)
# memory usage: 31.5 KB

# %%
df.Sex=df.Sex.astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       714 non-null    float64
#  4   Fare      891 non-null    float64
# dtypes: float64(2), int64(3)
# memory usage: 34.9 KB

# %%
df
# Out:
#      Survived  Pclass  Sex   Age     Fare
# 0           0       3    1  22.0   7.2500
# 1           1       1    0  38.0  71.2833
# 2           1       3    0  26.0   7.9250
# 3           1       1    0  35.0  53.1000
# 4           0       3    1  35.0   8.0500
# ..        ...     ...  ...   ...      ...
# 886         0       2    1  27.0  13.0000
# 887         1       1    0  19.0  30.0000
# 888         0       3    0   NaN  23.4500
# 889         1       1    1  26.0  30.0000
# 890         0       3    1  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Fare          0
# dtype: int64

# %%
df.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df.Age.median()
# Out:
# 28.0

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.Age.fillna(int(df.Age.mean()),inplace=True)

# %%
df.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  , 29.  , 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  , 16.  ,
#        25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  , 71.  ,
#        37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 , 51.  ,
#        55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  , 45.5 ,
#        20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  , 60.  ,
#        10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  , 70.  ,
#        24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Fare        0
# dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_classifier = DecisionTreeClassifier()

# %%
df
# Out:
#      Survived  Pclass  Sex   Age     Fare
# 0           0       3    1  22.0   7.2500
# 1           1       1    0  38.0  71.2833
# 2           1       3    0  26.0   7.9250
# 3           1       1    0  35.0  53.1000
# 4           0       3    1  35.0   8.0500
# ..        ...     ...  ...   ...      ...
# 886         0       2    1  27.0  13.0000
# 887         1       1    0  19.0  30.0000
# 888         0       3    0  29.0  23.4500
# 889         1       1    1  26.0  30.0000
# 890         0       3    1  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
sns.countplot(x='Sex',hue='Survived',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Survived',axis=1)

# %%
Y= df.Survived

# %%
X
# Out:
#      Pclass  Sex   Age     Fare
# 0         3    1  22.0   7.2500
# 1         1    0  38.0  71.2833
# 2         3    0  26.0   7.9250
# 3         1    0  35.0  53.1000
# 4         3    1  35.0   8.0500
# ..      ...  ...   ...      ...
# 886       2    1  27.0  13.0000
# 887       1    0  19.0  30.0000
# 888       3    0  29.0  23.4500
# 889       1    1  26.0  30.0000
# 890       3    1  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df
# Out:
#      Survived  Pclass  Sex   Age     Fare
# 0           0       3    1  22.0   7.2500
# 1           1       1    0  38.0  71.2833
# 2           1       3    0  26.0   7.9250
# 3           1       1    0  35.0  53.1000
# 4           0       3    1  35.0   8.0500
# ..        ...     ...  ...   ...      ...
# 886         0       2    1  27.0  13.0000
# 887         1       1    0  19.0  30.0000
# 888         0       3    0  29.0  23.4500
# 889         1       1    1  26.0  30.0000
# 890         0       3    1  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
tree_classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree_classifier.score(X_test,y_test)
# Out:
# 0.7988826815642458

# %%
tree_classifier.feature_importances_
# Out:
# array([0.11955656, 0.29676451, 0.2265927 , 0.35708623])

# %%
X
# Out:
#      Pclass  Sex   Age     Fare
# 0         3    1  22.0   7.2500
# 1         1    0  38.0  71.2833
# 2         3    0  26.0   7.9250
# 3         1    0  35.0  53.1000
# 4         3    1  35.0   8.0500
# ..      ...  ...   ...      ...
# 886       2    1  27.0  13.0000
# 887       1    0  19.0  30.0000
# 888       3    0  29.0  23.4500
# 889       1    1  26.0  30.0000
# 890       3    1  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
from sklearn import tree

# %%
plt.figure(figsize=(80,80))
tree.plot_tree(tree_classifier,filled=True)
# Out:
# [Text(0.3775542381432896, 0.9782608695652174, 'x[1] <= 0.5\ngini = 0.469\nsamples = 712\nvalue = [444, 268]'),
#  Text(0.19147325933400605, 0.9347826086956522, 'x[0] <= 2.5\ngini = 0.386\nsamples = 245\nvalue = [64, 181]'),
#  Text(0.03834510595358224, 0.8913043478260869, 'x[2] <= 2.5\ngini = 0.074\nsamples = 130\nvalue = [5, 125]'),
#  Text(0.016145307769929364, 0.8478260869565217, 'x[0] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.008072653884964682, 0.8043478260869565, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.024217961654894045, 0.8043478260869565, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.060544904137235116, 0.8478260869565217, 'x[2] <= 27.5\ngini = 0.061\nsamples = 128\nvalue = [4, 124]'),
#  Text(0.04036326942482341, 0.8043478260869565, 'x[2] <= 24.5\ngini = 0.12\nsamples = 47\nvalue = [3, 44]'),
#  Text(0.024217961654894045, 0.7608695652173914, 'x[3] <= 13.396\ngini = 0.048\nsamples = 41\nvalue = [1, 40]'),
# ...

# %%
tree_classifier.score(X_test,y_test)
# Out:
# 0.7988826815642458

# %%
X
# Out:
#      Pclass  Sex   Age     Fare
# 0         3    1  22.0   7.2500
# 1         1    0  38.0  71.2833
# 2         3    0  26.0   7.9250
# 3         1    0  35.0  53.1000
# 4         3    1  35.0   8.0500
# ..      ...  ...   ...      ...
# 886       2    1  27.0  13.0000
# 887       1    0  19.0  30.0000
# 888       3    0  29.0  23.4500
# 889       1    1  26.0  30.0000
# 890       3    1  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
df.Fare.median()
# Out:
# 14.4542

# %%
tree_classifier.predict([[2,0,25.0,14.45]])
# Out:
# C:\Users\yeshwanthr\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix

# %%
cn= confusion_matrix(y_test,tree_classifier.predict(X_test))

# %%
cn
# Out:
# array([[97, 20],
#        [16, 46]], dtype=int64)

# %%
sns.heatmap(cn,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(50.722222222222214, 0.5, 'Truth')

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.8268156424581006

# %%
cn=confusion_matrix(y_test,model.predict(X_test))

# %%
cn
# Out:
# array([[102,  15],
#        [ 16,  46]], dtype=int64)

# %%
df.corr()
# Out:
#           Survived    Pclass       Sex       Age      Fare
# Survived  1.000000 -0.338481 -0.543351 -0.067814  0.257307
# Pclass   -0.338481  1.000000  0.131900 -0.334974 -0.549500
# Sex      -0.543351  0.131900  1.000000  0.082949 -0.182333
# Age      -0.067814 -0.334974  0.082949  1.000000  0.093706
# Fare      0.257307 -0.549500 -0.182333  0.093706  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('adult.csv')

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.age.unique()
# Out:
# array([90, 82, 66, 54, 41, 34, 38, 74, 68, 45, 52, 32, 51, 46, 57, 22, 37,
#        29, 61, 21, 33, 49, 23, 59, 60, 63, 53, 44, 43, 71, 48, 73, 67, 40,
#        50, 42, 39, 55, 47, 31, 58, 62, 36, 72, 78, 83, 26, 70, 27, 35, 81,
#        65, 25, 28, 56, 69, 20, 30, 24, 64, 75, 19, 77, 80, 18, 17, 76, 79,
#        88, 84, 85, 86, 87], dtype=int64)

# %%
df.workclass.unique()
# Out:
# array(['?', 'Private', 'State-gov', 'Federal-gov', 'Self-emp-not-inc',
#        'Self-emp-inc', 'Local-gov', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
df.workclass=np.where(df.workclass=='?',np.nan,df.workclass)

# %%
df.workclass.unique()
# Out:
# array([nan, 'Private', 'State-gov', 'Federal-gov', 'Self-emp-not-inc',
#        'Self-emp-inc', 'Local-gov', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
df.fnlwgt.value_counts()
# Out:
# fnlwgt
# 164190    13
# 203488    13
# 123011    13
# 113364    12
# 121124    12
#           ..
# 183522     1
# 44419      1
# 442612     1
# 374833     1
# 257302     1
# Name: count, Length: 21648, dtype: int64

# %%
df.fnlwgt[df.fnlwgt=='?'].sum()
# Out:
# 0

# %%
df[df['education.num']=='?']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country, income]
# Index: []

# %%
df[df['marital.status']=='?']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country, income]
# Index: []

# %%
df[df['occupation']=='?']
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90       NaN   77053       HS-grad              9             Widowed
# 2       66       NaN  186061  Some-college             10             Widowed
# 14      51       NaN  172175     Doctorate             16       Never-married
# 24      61       NaN  135285       HS-grad              9  Married-civ-spouse
# 44      71       NaN  100820       HS-grad              9  Married-civ-spouse
# ...    ...       ...     ...           ...            ...                 ...
# 32533   35       NaN  320084     Bachelors             13  Married-civ-spouse
# 32534   30       NaN   33811     Bachelors             13       Never-married
# 32541   71       NaN  287372     Doctorate             16  Married-civ-spouse
# 32543   41       NaN  202822       HS-grad              9           Separated
# 32544   72       NaN  129912       HS-grad              9  Married-civ-spouse
#
# ...

# %%
df.occupation=np.where(df.occupation=='?',np.nan,df.occupation)

# %%
df[df['relationship']=='?']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country, income]
# Index: []

# %%
df[df['race']=='?']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country, income]
# Index: []

# %%
df[df['sex']=='?']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country, income]
# Index: []

# %%
df[df['capital.gain']=='?']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country, income]
# Index: []

# %%
df[df['hours.per.week']=='?']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country, income]
# Index: []

# %%
df[df['native.country']=='?']
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 9       41           Private   70037  Some-college             10
# 18      22           Private  119592    Assoc-acdm             12
# 65      60      Self-emp-inc  226355     Assoc-voc             11
# 86      39  Self-emp-not-inc  218490   Prof-school             15
# 87      43       Federal-gov  156996   Prof-school             15
# ...    ...               ...     ...           ...            ...
# 32459   44      Self-emp-inc   71556       Masters             14
# 32476   58      Self-emp-inc  181974     Doctorate             16
# 32498   42  Self-emp-not-inc  217597       HS-grad              9
# 32515   39           Private  107302       HS-grad              9
# 32528   81               NaN  120478     Assoc-voc             11
#
#            marital.status         occupation   relationship  \
# 9           Never-married       Craft-repair      Unmarried
# ...

# %%
df['native.country']=np.where(df['native.country']=='?',np.nan,df['native.country'])

# %%
df[df['income']=='?']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country, income]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  31978 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df[['education','education.num']].head(100)
pd.set_option('display.max_rows',200)

# %%
df[['education','education.num']].head(100)
# Out:
#        education  education.num
# 0        HS-grad              9
# 1        HS-grad              9
# 2   Some-college             10
# 3        7th-8th              4
# 4   Some-college             10
# 5        HS-grad              9
# 6           10th              6
# 7      Doctorate             16
# 8        HS-grad              9
# 9   Some-college             10
# 10     Doctorate             16
# 11   Prof-school             15
# 12     Bachelors             13
# 13       Masters             14
# 14     Doctorate             16
# 15   Prof-school             15
# 16          11th              7
# 17       Masters             14
# 18    Assoc-acdm             12
# 19     Bachelors             13
# 20     Bachelors             13
# 21          11th              7
# 22       HS-grad              9
# 23  Some-college             10
# 24       HS-grad              9
# 25     Assoc-voc             11
# 26       1st-4th              2
# 27       5th-6th              3
# ...

# %%
df.drop('education',axis=1,inplace=True)

# %%
df
# Out:
#        age workclass  fnlwgt  education.num      marital.status  \
# 0       90       NaN   77053              9             Widowed
# 1       82   Private  132870              9             Widowed
# 2       66       NaN  186061             10             Widowed
# 3       54   Private  140359              4            Divorced
# 4       41   Private  264663             10           Separated
# ...    ...       ...     ...            ...                 ...
# 32556   22   Private  310152             10       Never-married
# 32557   27   Private  257302             12  Married-civ-spouse
# 32558   40   Private  154374              9  Married-civ-spouse
# 32559   58   Private  151910              9             Widowed
# 32560   22   Private  201490              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 0                    NaN  Not-in-family  White  Female             0
# ...

# %%
df.income.value_counts()
# Out:
# income
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64

# %%
df.workclass.fillna(df.workclass.mode()[0],inplace=True)

# %%
df['native.country'].fillna(df['native.country'].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education.num   32561 non-null  int64
#  4   marital.status  32561 non-null  object
#  5   occupation      30718 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital.gain    32561 non-null  int64
#  10  capital.loss    32561 non-null  int64
#  11  hours.per.week  32561 non-null  int64
#  12  native.country  32561 non-null  object
#  13  income          32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
df.occupation.value_counts()
# Out:
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: count, dtype: int64

# %%
df.occupation.fillna(df.occupation.mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education.num   32561 non-null  int64
#  4   marital.status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital.gain    32561 non-null  int64
#  10  capital.loss    32561 non-null  int64
#  11  hours.per.week  32561 non-null  int64
#  12  native.country  32561 non-null  object
#  13  income          32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
df
# Out:
#        age workclass  fnlwgt  education.num      marital.status  \
# 0       90   Private   77053              9             Widowed
# 1       82   Private  132870              9             Widowed
# 2       66   Private  186061             10             Widowed
# 3       54   Private  140359              4            Divorced
# 4       41   Private  264663             10           Separated
# ...    ...       ...     ...            ...                 ...
# 32556   22   Private  310152             10       Never-married
# 32557   27   Private  257302             12  Married-civ-spouse
# 32558   40   Private  154374              9  Married-civ-spouse
# 32559   58   Private  151910              9             Widowed
# 32560   22   Private  201490              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 0         Prof-specialty  Not-in-family  White  Female             0
# ...

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             24532
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
df['capital.gain'].value_counts()
# Out:
# capital.gain
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
# 5178        97
# 3103        97
# 4386        70
# 5013        69
# 8614        55
# 3325        53
# 2174        48
# 10520       43
# 4064        42
# 4650        41
# 14084       41
# 20051       37
# 3137        37
# 594         34
# 27828       34
# 3908        32
# 2829        31
# 13550       27
# 6849        27
# 14344       26
# 1055        25
# 3411        24
# 2885        24
# 3464        23
# 2176        23
# 4787        23
# 9386        22
# 4101        20
# 2597        20
# 2407        19
# 4865        17
# 2202        16
# 1506        15
# 3942        14
# 3674        14
# 2580        12
# 10605       12
# 3781        12
# 4508        12
# 4416        12
# 5455        11
# 6497        11
# 25236       11
# 2354        11
# 2463        11
# 2907        11
# 2635        11
# 6418         9
# 7430         9
# 2105         9
# 2964         9
# 1151         8
# ...

# %%
df
# Out:
#        age workclass  fnlwgt  education.num      marital.status  \
# 0       90   Private   77053              9             Widowed
# 1       82   Private  132870              9             Widowed
# 2       66   Private  186061             10             Widowed
# 3       54   Private  140359              4            Divorced
# 4       41   Private  264663             10           Separated
# ...    ...       ...     ...            ...                 ...
# 32556   22   Private  310152             10       Never-married
# 32557   27   Private  257302             12  Married-civ-spouse
# 32558   40   Private  154374              9  Married-civ-spouse
# 32559   58   Private  151910              9             Widowed
# 32560   22   Private  201490              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 0         Prof-specialty  Not-in-family  White  Female             0
# ...

# %%
sns.countplot(x='income',data=df,hue='sex')
# Out:
# <Axes: xlabel='income', ylabel='count'>

# %%
sns.distplot(x=df.age,bins=50)
# Out:
# C:\Users\yeshwanthr\AppData\Local\Temp\ipykernel_31540\3158157143.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df.age,bins=50)
# <Axes: ylabel='Density'>

# %%
sns.countplot(x='race',data=df)
# Out:
# <Axes: xlabel='race', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education.num   32561 non-null  int64
#  4   marital.status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital.gain    32561 non-null  int64
#  10  capital.loss    32561 non-null  int64
#  11  hours.per.week  32561 non-null  int64
#  12  native.country  32561 non-null  object
#  13  income          32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
df.age.dtype
# Out:
# dtype('int64')

# %%
num_cols = [column for column in df.columns if df[column].dtype=='int64']

# %%
for col in num_cols:
    print(col)
    plt.figure(figsize=(6, 4))
    sns.histplot(x=col,data=df,kde=True)
    plt.show()
# Out:
# age
# fnlwgt
# education.num
# capital.gain
# capital.loss
# hours.per.week

# %%
categorical_cols = [column for column in df.columns if df[column].dtype=='O']

# %%
categorical_cols
# Out:
# ['workclass',
#  'marital.status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native.country',
#  'income']

# %%
for col in categorical_cols:
    print(col)
    plt.figure(figsize=(16, 8))
    sns.countplot(x=col,data=df)
    plt.xticks(rotation=90)
    plt.show()
# Out:
# workclass
# marital.status
# occupation
# relationship
# race
# sex
# native.country
# income

# %%
for col in categorical_cols:
    print(col)
    plt.figure(figsize=(16, 8))
    sns.countplot(x=col,data=df,hue='income')
    plt.xticks(rotation=90)
    plt.show()
# Out:
# workclass
# marital.status
# occupation
# relationship
# race
# sex
# native.country
# income

# %%
for col in num_cols:
    print(col)
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=col,data=df)
    plt.show()
# Out:
# age
# fnlwgt
# education.num
# capital.gain
# capital.loss
# hours.per.week

# %%
sns.pairplot(df)
# Out:
# C:\Users\yeshwanthr\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(data=df[num_cols].corr())
# Out:
# <Axes: >

# %% [markdown]
# **Outlier Removal**

# %%
num_cols
# Out:
# ['age',
#  'fnlwgt',
#  'education.num',
#  'capital.gain',
#  'capital.loss',
#  'hours.per.week']

# %%
df.age.describe()
# Out:
# count    32561.000000
# mean        38.581647
# std         13.640433
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
df_with_outliers =df.copy()

# %%
df = df_with_outliers.copy()

# %%
upper_outlier = df.age.quantile(0.75) + 1.5*(df.age.quantile(0.75)-df.age.quantile(0.25))
upper_outlier
# Out:
# 78.0

# %%
lower_outlier = df.age.quantile(0.25) - 1.5*(df.age.quantile(0.75)-df.age.quantile(0.25))
lower_outlier
# Out:
# -2.0

# %%
df = df[df.age<(df.age.quantile(0.75) + 1.5*(df.age.quantile(0.75)-df.age.quantile(0.25)))]

# %%
df.shape
# Out:
# (32395, 14)

# %%
df = df[df.fnlwgt<(df.fnlwgt.quantile(0.75) + 1.5*(df.fnlwgt.quantile(0.75)-df.fnlwgt.quantile(0.25)))]

# %%
df.shape
# Out:
# (31414, 14)

# %%
df[df['hours.per.week']>(df['hours.per.week'].quantile(0.75) + 3*(df['hours.per.week'].quantile(0.75)-df['hours.per.week'].quantile(0.25)))].shape
# Out:
# (1082, 14)

# %%
df[df['hours.per.week']<(df['hours.per.week'].quantile(0.25) - 3*(df['hours.per.week'].quantile(0.75)-df['hours.per.week'].quantile(0.25)))].shape
# Out:
# (3095, 14)

# %%
df['hours.per.week'].describe()
# Out:
# count    31414.000000
# mean        40.527567
# std         12.309286
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours.per.week, dtype: float64

# %%
df[df['hours.per.week']>df['hours.per.week'].mean() + 3*df['hours.per.week'].std()].shape
# Out:
# (339, 14)

# %%
df[df['hours.per.week']<df['hours.per.week'].mean() - 3*df['hours.per.week'].std()].shape
# Out:
# (75, 14)

# %%
higher_outlier = df['hours.per.week'].mean() + 3*df['hours.per.week'].std()
higher_outlier
# Out:
# 77.45542649221574

# %%
lower_outlier = df['hours.per.week'].mean() - 3*df['hours.per.week'].std()
lower_outlier
# Out:
# 3.5997081611235444

# %%
df = df[df['hours.per.week']<higher_outlier]

# %%
df = df[df['hours.per.week']>lower_outlier]

# %%
df.shape
# Out:
# (31000, 14)

# %%
df = df[df['capital.gain']<40000]

# %%
df = df[df['capital.loss']<3000]

# %%
df.shape
# Out:
# (30840, 14)

# %%
df
# Out:
#        age         workclass  fnlwgt  education.num      marital.status  \
# 11      38  Self-emp-not-inc  164526             15       Never-married
# 12      52           Private  129177             13             Widowed
# 13      32           Private  136204             14           Separated
# 14      51           Private  172175             16       Never-married
# 15      46           Private   45363             15            Divorced
# ...    ...               ...     ...            ...                 ...
# 32556   22           Private  310152             10       Never-married
# 32557   27           Private  257302             12  Married-civ-spouse
# 32558   40           Private  154374              9  Married-civ-spouse
# 32559   58           Private  151910              9             Widowed
# 32560   22           Private  201490              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# ...

# %% [markdown]
# **Encoding the categorical columns**

# %%
df_without_category_encoding = df.copy()

# %%
df = pd.concat([df,pd.get_dummies(df.sex,drop_first=True,dtype=int)],axis=1)

# %%
df.drop('sex',inplace=True,axis=1)

# %%
df
# Out:
#        age         workclass  fnlwgt  education.num      marital.status  \
# 11      38  Self-emp-not-inc  164526             15       Never-married
# 12      52           Private  129177             13             Widowed
# 13      32           Private  136204             14           Separated
# 14      51           Private  172175             16       Never-married
# 15      46           Private   45363             15            Divorced
# ...    ...               ...     ...            ...                 ...
# 32556   22           Private  310152             10       Never-married
# 32557   27           Private  257302             12  Married-civ-spouse
# 32558   40           Private  154374              9  Married-civ-spouse
# 32559   58           Private  151910              9             Widowed
# 32560   22           Private  201490              9       Never-married
#
#               occupation   relationship   race  capital.gain  capital.loss  \
# ...

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             23309
# Self-emp-not-inc     2335
# Local-gov            2013
# State-gov            1243
# Self-emp-inc         1008
# Federal-gov           912
# Without-pay            14
# Never-worked            6
# Name: count, dtype: int64

# %%
df['marital.status'].value_counts()
# Out:
# marital.status
# Married-civ-spouse       14107
# Never-married            10183
# Divorced                  4254
# Separated                  974
# Widowed                    908
# Married-spouse-absent      396
# Married-AF-spouse           18
# Name: count, dtype: int64

# %%
df.occupation.value_counts()
# Out:
# occupation
# Prof-specialty       5569
# Craft-repair         3930
# Exec-managerial      3835
# Adm-clerical         3638
# Sales                3465
# Other-service        3132
# Machine-op-inspct    1933
# Transport-moving     1505
# Handlers-cleaners    1294
# Farming-fishing       889
# Tech-support          887
# Protective-serv       613
# Priv-house-serv       141
# Armed-Forces            9
# Name: count, dtype: int64

# %%
df.relationship.value_counts()
# Out:
# relationship
# Husband           12403
# Not-in-family      7871
# Own-child          4852
# Unmarried          3289
# Wife               1499
# Other-relative      926
# Name: count, dtype: int64

# %%
df.race.value_counts()
# Out:
# race
# White                 26398
# Black                  2874
# Asian-Pac-Islander     1000
# Amer-Indian-Eskimo      305
# Other                   263
# Name: count, dtype: int64

# %%
df['native.country'].value_counts()
# Out:
# native.country
# United-States                 28237
# Mexico                          544
# Philippines                     192
# Germany                         134
# Canada                          116
# Puerto-Rico                     109
# India                            96
# El-Salvador                      93
# Cuba                             93
# England                          85
# Jamaica                          81
# South                            76
# China                            74
# Italy                            69
# Dominican-Republic               67
# Vietnam                          66
# Columbia                         57
# Poland                           57
# Japan                            56
# Guatemala                        52
# Taiwan                           47
# Haiti                            44
# Iran                             42
# Portugal                         35
# Nicaragua                        29
# ...

# %%
df.income.value_counts()
# Out:
# income
# <=50K    23519
# >50K      7321
# Name: count, dtype: int64

# %%
pd.get_dummies(df.income,drop_first=True,dtype=int)
# Out:
#        >50K
# 11        1
# 12        1
# 13        1
# 14        1
# 15        1
# ...     ...
# 32556     0
# 32557     0
# 32558     1
# 32559     0
# 32560     0
#
# [30840 rows x 1 columns]

# %%
df = pd.concat([df,pd.get_dummies(df.income,drop_first=True,dtype=int)],axis=1)

# %%
df
# Out:
#        age         workclass  fnlwgt  education.num      marital.status  \
# 11      38  Self-emp-not-inc  164526             15       Never-married
# 12      52           Private  129177             13             Widowed
# 13      32           Private  136204             14           Separated
# 14      51           Private  172175             16       Never-married
# 15      46           Private   45363             15            Divorced
# ...    ...               ...     ...            ...                 ...
# 32556   22           Private  310152             10       Never-married
# 32557   27           Private  257302             12  Married-civ-spouse
# 32558   40           Private  154374              9  Married-civ-spouse
# 32559   58           Private  151910              9             Widowed
# 32560   22           Private  201490              9       Never-married
#
#               occupation   relationship   race  capital.gain  capital.loss  \
# ...

# %%
df.drop('income',inplace=True,axis=1)

# %%
df.reset_index(inplace=True)
# Out:
#        level_0  index  age         workclass  fnlwgt  education.num  \
# 0            0     11   38  Self-emp-not-inc  164526             15
# 1            1     12   52           Private  129177             13
# 2            2     13   32           Private  136204             14
# 3            3     14   51           Private  172175             16
# 4            4     15   46           Private   45363             15
# ...        ...    ...  ...               ...     ...            ...
# 30835    30835  32556   22           Private  310152             10
# 30836    30836  32557   27           Private  257302             12
# 30837    30837  32558   40           Private  154374              9
# 30838    30838  32559   58           Private  151910              9
# 30839    30839  32560   22           Private  201490              9
#
#            marital.status         occupation   relationship   race  \
# 0           Never-married     Prof-specialty  Not-in-family  White
# ...

# %%
df.drop(['index','level_0'],inplace=True,axis=1)

# %%
df
# Out:
#        age         workclass  fnlwgt  education.num      marital.status  \
# 0       38  Self-emp-not-inc  164526             15       Never-married
# 1       52           Private  129177             13             Widowed
# 2       32           Private  136204             14           Separated
# 3       51           Private  172175             16       Never-married
# 4       46           Private   45363             15            Divorced
# ...    ...               ...     ...            ...                 ...
# 30835   22           Private  310152             10       Never-married
# 30836   27           Private  257302             12  Married-civ-spouse
# 30837   40           Private  154374              9  Married-civ-spouse
# 30838   58           Private  151910              9             Widowed
# 30839   22           Private  201490              9       Never-married
#
#               occupation   relationship   race  capital.gain  capital.loss  \
# ...

# %%
grouped_workclass = df.groupby('workclass')['>50K'].mean().reset_index()

# %%
grouped_workclass.columns = ['workclass','workclass_encoded']

# %%
df=df.merge(grouped_workclass,on='workclass',how='left')

# %%
df
# Out:
#        age         workclass  fnlwgt  education.num      marital.status  \
# 0       38  Self-emp-not-inc  164526             15       Never-married
# 1       52           Private  129177             13             Widowed
# 2       32           Private  136204             14           Separated
# 3       51           Private  172175             16       Never-married
# 4       46           Private   45363             15            Divorced
# ...    ...               ...     ...            ...                 ...
# 30835   22           Private  310152             10       Never-married
# 30836   27           Private  257302             12  Married-civ-spouse
# 30837   40           Private  154374              9  Married-civ-spouse
# 30838   58           Private  151910              9             Widowed
# 30839   22           Private  201490              9       Never-married
#
#               occupation   relationship   race  capital.gain  capital.loss  \
# ...

# %%
df.drop('workclass',axis=1,inplace=True)

# %%
grouped_marital = df.groupby('marital.status')['>50K'].mean().reset_index()
grouped_marital.columns = ['marital.status','marital_encoded']
df=df.merge(grouped_marital,on='marital.status',how='left')
df.drop('marital.status',axis=1,inplace=True)
df
# Out:
#        age  fnlwgt  education.num         occupation   relationship   race  \
# 0       38  164526             15     Prof-specialty  Not-in-family  White
# 1       52  129177             13      Other-service  Not-in-family  White
# 2       32  136204             14    Exec-managerial  Not-in-family  White
# 3       51  172175             16     Prof-specialty  Not-in-family  White
# 4       46   45363             15     Prof-specialty  Not-in-family  White
# ...    ...     ...            ...                ...            ...    ...
# 30835   22  310152             10    Protective-serv  Not-in-family  White
# 30836   27  257302             12       Tech-support           Wife  White
# 30837   40  154374              9  Machine-op-inspct        Husband  White
# 30838   58  151910              9       Adm-clerical      Unmarried  White
# 30839   22  201490              9       Adm-clerical      Own-child  White
#
# ...

# %%
grouped_occupation = df.groupby('occupation')['>50K'].mean().reset_index()
grouped_occupation.columns = ['occupation','occupation_encoded']
df=df.merge(grouped_occupation,on='occupation',how='left')
df.drop('occupation',axis=1,inplace=True)
df
# Out:
#        age  fnlwgt  education.num   relationship   race  capital.gain  \
# 0       38  164526             15  Not-in-family  White             0
# 1       52  129177             13  Not-in-family  White             0
# 2       32  136204             14  Not-in-family  White             0
# 3       51  172175             16  Not-in-family  White             0
# 4       46   45363             15  Not-in-family  White             0
# ...    ...     ...            ...            ...    ...           ...
# 30835   22  310152             10  Not-in-family  White             0
# 30836   27  257302             12           Wife  White             0
# 30837   40  154374              9        Husband  White             0
# 30838   58  151910              9      Unmarried  White             0
# 30839   22  201490              9      Own-child  White             0
#
#        capital.loss  hours.per.week native.country  Male  >50K  \
# ...

# %%
grouped_relationship = df.groupby('relationship')['>50K'].mean().reset_index()
grouped_relationship.columns = ['relationship','relationship_encoded']
df=df.merge(grouped_relationship,on='relationship',how='left')
df.drop('relationship',axis=1,inplace=True)
df
# Out:
#        age  fnlwgt  education.num   race  capital.gain  capital.loss  \
# 0       38  164526             15  White             0          2824
# 1       52  129177             13  White             0          2824
# 2       32  136204             14  White             0          2824
# 3       51  172175             16  White             0          2824
# 4       46   45363             15  White             0          2824
# ...    ...     ...            ...    ...           ...           ...
# 30835   22  310152             10  White             0             0
# 30836   27  257302             12  White             0             0
# 30837   40  154374              9  White             0             0
# 30838   58  151910              9  White             0             0
# 30839   22  201490              9  White             0             0
#
#        hours.per.week native.country  Male  >50K  workclass_encoded  \
# 0                  45  United-States     1     1           0.280942
# ...

# %%
grouped_race = df.groupby('race')['>50K'].mean().reset_index()
grouped_race.columns = ['race','race_encoded']
df=df.merge(grouped_race,on='race',how='left')
df.drop('race',axis=1,inplace=True)
df
# Out:
#        age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 0       38  164526             15             0          2824              45
# 1       52  129177             13             0          2824              20
# 2       32  136204             14             0          2824              55
# 3       51  172175             16             0          2824              40
# 4       46   45363             15             0          2824              40
# ...    ...     ...            ...           ...           ...             ...
# 30835   22  310152             10             0             0              40
# 30836   27  257302             12             0             0              38
# 30837   40  154374              9             0             0              40
# 30838   58  151910              9             0             0              40
# 30839   22  201490              9             0             0              20
#
# ...

# %%
df.groupby('native.country')['>50K'].mean().reset_index()
# Out:
#                 native.country      >50K
# 0                     Cambodia  0.368421
# 1                       Canada  0.301724
# 2                        China  0.270270
# 3                     Columbia  0.035088
# 4                         Cuba  0.258065
# 5           Dominican-Republic  0.014925
# 6                      Ecuador  0.111111
# 7                  El-Salvador  0.086022
# 8                      England  0.329412
# 9                       France  0.407407
# 10                     Germany  0.320896
# 11                      Greece  0.275862
# 12                   Guatemala  0.057692
# 13                       Haiti  0.090909
# 14          Holand-Netherlands  0.000000
# 15                    Honduras  0.076923
# 16                        Hong  0.300000
# 17                     Hungary  0.250000
# 18                       India  0.385417
# 19                        Iran  0.428571
# 20                     Ireland  0.208333
# 21                       Italy  0.347826
# ...

# %%
def country(value):
    if value=='United-States':
        return 1
    return 0

# %%
df['native.country']=df['native.country'].apply(country)

# %%
df
# Out:
#        age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 0       38  164526             15             0          2824              45
# 1       52  129177             13             0          2824              20
# 2       32  136204             14             0          2824              55
# 3       51  172175             16             0          2824              40
# 4       46   45363             15             0          2824              40
# ...    ...     ...            ...           ...           ...             ...
# 30835   22  310152             10             0             0              40
# 30836   27  257302             12             0             0              38
# 30837   40  154374              9             0             0              40
# 30838   58  151910              9             0             0              40
# 30839   22  201490              9             0             0              20
#
# ...

# %%
df_without_scaling = df.copy()

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
df_x = pd.DataFrame(ss.fit_transform(df.drop('>50K',axis=1)))

# %%
df_x.columns=df.drop('>50K',axis=1).columns

# %%
df_x
# Out:
#             age    fnlwgt  education.num  capital.gain  capital.loss  \
# 0     -0.026706 -0.176463       1.933522     -0.232148      6.841976
# 1      1.027577 -0.580967       1.147404     -0.232148      6.841976
# 2     -0.478542 -0.500556       1.540463     -0.232148      6.841976
# 3      0.952271 -0.088935       2.326581     -0.232148      6.841976
# 4      0.575741 -1.540063       1.933522     -0.232148      6.841976
# ...         ...       ...            ...           ...           ...
# 30835 -1.231602  1.489957      -0.031774     -0.232148     -0.218674
# 30836 -0.855072  0.885187       0.754345     -0.232148     -0.218674
# 30837  0.123906 -0.292634      -0.424833     -0.232148     -0.218674
# 30838  1.479413 -0.320830      -0.424833     -0.232148     -0.218674
# 30839 -1.231602  0.246521      -0.424833     -0.232148     -0.218674
#
#        hours.per.week  native.country      Male  workclass_encoded  \
# 0            0.442099        0.303618  0.709946           0.624648
# ...

# %%
df_y = df['>50K']
df_y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 30835    0
# 30836    0
# 30837    1
# 30838    0
# 30839    0
# Name: >50K, Length: 30840, dtype: int32

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
pca = PCA(n_components=12)
x_pca=pca.fit_transform(df_x)
print(pca.explained_variance_ratio_)
cvs=cross_val_score(estimator = LogisticRegression(),X=x_pca,y=df_y,cv=5,scoring='accuracy').mean()
cvs
# Out:
# [0.21724354 0.11269721 0.08275112 0.0819341  0.0786501  0.07378984
#  0.07102983 0.06649847 0.06441863 0.05690765 0.04879963 0.04312882]
# 0.8261024643320363

# %%
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
pca = PCA(n_components=12)
x_pca=pca.fit_transform(df_x)
print(pca.explained_variance_ratio_)
cvs=cross_val_score(estimator = RandomForestClassifier(n_estimators=100,random_state=42),X=x_pca,y=df_y,cv=5,scoring='accuracy').mean()
cvs
# Out:
# [0.21724354 0.11269721 0.08275112 0.0819341  0.0786501  0.07378984
#  0.07102983 0.06649847 0.06441863 0.05690765 0.04879963 0.04312882]
# 0.8286316472114137

# %%
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA
from sklearn.naive_bayes import GaussianNB
pca = PCA(n_components=12)
x_pca=pca.fit_transform(df_x)
print(pca.explained_variance_ratio_)
cvs=cross_val_score(estimator = GaussianNB(),X=x_pca,y=df_y,cv=5,scoring='accuracy').mean()
cvs
# Out:
# [0.21724354 0.11269721 0.08275112 0.0819341  0.0786501  0.07378984
#  0.07102983 0.06649847 0.06441863 0.05690765 0.04879963 0.04312882]
# 0.8013294422827496

# %% [markdown]
# **As we can see the best model is RandomForestClassifier**
